# %% [markdown]
# <a href="https://colab.research.google.com/github/PrathibhaNishadi/Cricket-Squad-Selector/blob/main/TestBall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from keras.optimizers import Adam
import keras
from sklearn.model_selection import train_test_split
import numpy as np
import argparse
import locale
import os
from sklearn.preprocessing import LabelBinarizer
import pandas as pd
import numpy as np
import glob
import cv2
import os
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model


def load_data_attributes(inputPath):
	df = pd.read_csv(inputPath)
	return df

def process_data_attributes(df, train, test):
  continuous = ["TMatches","Twickets", "InEcon", "InSR"]
  trainX = (train[continuous])
  testX = (test[continuous])
  return (trainX, testX)

def create_mlp(dim, regress=False):
	model = Sequential()
	model.add(Dense(13, input_dim=4, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))

	if regress:
		model.add(Dense(1, activation="linear"))

	return model


print("[INFO] loading Cricket attributes...")

df = load_data_attributes("drive/My Drive/Project/TestBallTrain.csv")

print("[INFO] constructing training/testing split...")
(train, test) = train_test_split(df, test_size=0.10, random_state=42)
_trainY = train["Wickets"]
_testY = test["Wickets"]
trainY=[]

for i in _trainY:
  trainY.append(i)
print(trainY)
testY=[]

for i in _testY:
  testY.append(i)
print(testY)

trainY=np.array(trainY)
testY=np.array(testY)

print("[INFO] processing data...")
(trainX, testX) = process_data_attributes(df, train, test)

model = create_mlp(trainX.shape[1], regress=True)
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss='mean_squared_error', optimizer='adam')


print("[INFO] training model...")

model.fit(trainX, trainY, validation_data=(testX, testY),
	epochs=200, batch_size=8)

model.save('TestBall_model.mod')

# %%
import csv
import keras
import pandas as pd

predict=pd.read_csv("drive/My Drive/Project/TestBalling.csv")
labels = ["Matches","Wickets", "InEcon", "InSR"]
predictList=(predict[labels])

model=keras.models.load_model('TestBall_model.mod')
results=model.predict(predictList)
results=results


output = results.tolist()
names = (predict["Name"])
types = (predict["Type"])

myFile = open('TestBallResults.csv', 'w')  
with myFile:  
    myFields = ['Name','Type', 'Wickets']
    writer = csv.DictWriter(myFile, fieldnames=myFields)    
    writer.writeheader()
    
    for i in range(len(output)):
      writer.writerow({'Name' : names[i],'Type' : types[i], 'Wickets': output[i][0]})
      
# making data frame from csv file 
data = pd.read_csv("TestBallResults.csv")

# creating a rank column and passing the returned rank series 
data["Rank"] = data["Wickets"].rank(ascending=0)

# sorting w.r.t name column 
data.sort_values("Rank", inplace = True)  

export_csv = data.to_csv ('TestBallResults.csv', index = None, header=True)

data
# Out:
#                     Name             Type   Wickets  Rank
# 2        Dilruwan Perera       Allrounder  2.156266   1.0
# 8       Lakshan Sandakan           Bowler  1.877525   2.0
# 12       Vishwa Fernando           Bowler  1.737026   3.0
# 4         Suranga Lakmal           Bowler  1.648392   4.0
# 7     Lasith Embuldeniya           Bowler  1.623955   5.0
# 3          Lahiru Kumara           Bowler  1.614243   6.0
# 6        Akila Dananjaya       Allrounder  1.558961   7.0
# 0   Malinda Pushpakumara       Allrounder  1.556220   8.0
# 10         Kasun Rajitha           Bowler  1.378208   9.0
# 1    Chamika Karunaratne           Bowler  1.134454  10.0
# 9    Dushmantha Chameera           Bowler  1.054510  11.0
# 11   Dhananjaya de Silva       Allrounder -1.824455  12.0
# 5     Dimuth Karunaratne  Opening batsman -3.046698  13.0
