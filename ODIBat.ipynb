# %% [markdown]
# <a href="https://colab.research.google.com/github/PrathibhaNishadi/Cricket-Squad-Selector/blob/main/ODIBat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from keras.optimizers import Adam
import keras
from sklearn.model_selection import train_test_split
import numpy as np
import argparse
import locale
import os
from sklearn.preprocessing import LabelBinarizer
import pandas as pd
import numpy as np
import glob
import cv2
import os
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model


def load_data_attributes(inputPath):
	df = pd.read_csv(inputPath)
	return df

def process_data_attributes(df, train, test):
  continuous = ["TMatches","Avg", "SR", "TBoun"]
  trainX = (train[continuous])
  testX = (test[continuous])
  return (trainX, testX)

def create_mlp(dim, regress=False):
	model = Sequential()
	model.add(Dense(13, input_dim=4, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))

	if regress:
		model.add(Dense(1, activation="linear"))

	return model


print("[INFO] loading Cricket attributes...")

df = load_data_attributes("drive/My Drive/Project/ODIBatTrain.csv")

print("[INFO] constructing training/testing split...")
(train, test) = train_test_split(df, test_size=0.10, random_state=42)
_trainY = train["Runs"]
_testY = test["Runs"]
trainY=[]

for i in _trainY:
  trainY.append(i)
print(trainY)
testY=[]

for i in _testY:
  testY.append(i)
print(testY)

trainY=np.array(trainY)
testY=np.array(testY)

print("[INFO] processing data...")
(trainX, testX) = process_data_attributes(df, train, test)

model = create_mlp(trainX.shape[1], regress=True)
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss='mean_squared_error', optimizer='adam')


print("[INFO] training model...")

model.fit(trainX, trainY, validation_data=(testX, testY),
	epochs=200, batch_size=8)

model.save('ODIBat_model.mod')

# %%
import csv
import keras
import pandas as pd

predict=pd.read_csv("drive/My Drive/Project/ODIBatting.csv")
labels = ["Matches","BatAvg", "StrikeRate", "Boundaries"]
predictList=(predict[labels])


model=keras.models.load_model('ODIBat_model.mod')
results=model.predict(predictList)
results=results


output = results.tolist()
names = (predict["Name"])
types = (predict["Type"])

myFile = open('ODIBatResults.csv', 'w')  
with myFile:  
    myFields = ['Name','Type' ,'Runs']
    writer = csv.DictWriter(myFile, fieldnames=myFields)    
    writer.writeheader()
    
    for i in range(len(output)):
      writer.writerow({'Name' : names[i], 'Type' : types[i], 'Runs': output[i][0]})
      
# making data frame from csv file 
data = pd.read_csv("ODIBatResults.csv")

# creating a rank column and passing the returned rank series 
data["Rank"] = data["Runs"].rank(ascending=0)

# sorting w.r.t name column 
data.sort_values("Rank", inplace = True)  

export_csv = data.to_csv ('ODIBatResults.csv', index = None, header=True)

data
# Out:
#                       Name                  Type       Runs  Rank
# 3           Thisara Perera            Allrounder  39.503170   1.0
# 0             Kusal Perera  Wicketkeeper batsman  32.858639   2.0
# 4       Niroshan Dickwella  Wicketkeeper batsman  32.415154   3.0
# 2      Dhananjaya de Silva            Allrounder  30.677605   4.0
# 15          Angelo Mathews            Allrounder  27.987221   5.0
# 5             Kusal Mendis  Wicketkeeper batsman  27.610964   6.0
# 6     Danushka Gunathilaka            Allrounder  25.659569   7.0
# 9              Isuru Udana            Allrounder  24.578251   8.0
# 12         Oshada Fernando               Batsman  23.973251   9.0
# 1            Dasun Shanaka            Allrounder  23.349171  10.0
# 14           Upul Tharanga               Batsman  20.474501  11.0
# 11  Sadeera Samarawickrama  Wicketkeeper batsman  19.652519  12.0
# 13        Dinesh Chandimal  Wicketkeeper batsman  18.943312  13.0
# 10        Avishka Fernando       Opening batsman  18.284134  14.0
# 29         Dilruwan Perera            Allrounder  16.184566  15.0
# 26           Angelo Perera            Allrounder  15.832158  16.0
# 21          Kamindu Mendis            Allrounder  14.586769  17.0
# 30         Priyamal Perera  Middle-order batsman  14.297495  18.0
# 17            Amila Aponso                Bowler  13.423410  19.0
# 19         Vishwa Fernando                Bowler  13.349807  20.0
# 16     Dushmantha Chameera                Bowler  12.719207  21.0
# 27       Shehan Jayasuriya    Batting allrounder  12.467636  22.0
# 31          Suranga Lakmal                Bowler  12.074146  23.0
# 18           Kasun Rajitha                Bowler  12.063004  24.0
# 25         Asela Gunaratne               Batsman  12.024495  25.0
# 20           Lahiru Kumara                Bowler  11.554477  26.0
# 28      Prabath Jayasuriya                Bowler  10.536371  27.0
# 7          Akila Dananjaya            Allrounder  10.199693  28.0
# 22       Seekkuge Prasanna            Allrounder   9.626203  29.0
# 24        Lakshan Sandakan                Bowler   9.422775  30.0
# 23           Nuwan Pradeep                Bowler   7.752784  31.0
# 8           Lasith Malinga                Bowler   5.975712  32.0
