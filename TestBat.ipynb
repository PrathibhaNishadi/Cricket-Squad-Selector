# %% [markdown]
# <a href="https://colab.research.google.com/github/PrathibhaNishadi/Cricket-Squad-Selector/blob/main/TestBat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from keras.optimizers import Adam
import keras
from sklearn.model_selection import train_test_split
import numpy as np
import argparse
import locale
import os
from sklearn.preprocessing import LabelBinarizer
import pandas as pd
import numpy as np
import glob
import cv2
import os
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model


def load_data_attributes(inputPath):
	df = pd.read_csv(inputPath)
	return df

def process_data_attributes(df, train, test):
  continuous = ["Tinns", "Avg", "SR", "FiftyPlus"]
  trainX = (train[continuous])
  testX = (test[continuous])
  return (trainX, testX)

def create_mlp(dim, regress=False):
	model = Sequential()
	model.add(Dense(13, input_dim=4, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))

	if regress:
		model.add(Dense(1, activation="linear"))

	return model


print("[INFO] loading Cricket attributes...")

df = load_data_attributes("drive/My Drive/Project/TestBatTrain.csv")

print("[INFO] constructing training/testing split...")
(train, test) = train_test_split(df, test_size=0.10, random_state=42)
_trainY = train["Runs"]
_testY = test["Runs"]
trainY=[]

for i in _trainY:
  trainY.append(i)
print(trainY)
testY=[]

for i in _testY:
  testY.append(i)
print(testY)

trainY=np.array(trainY)
testY=np.array(testY)

print("[INFO] processing data...")
(trainX, testX) = process_data_attributes(df, train, test)

model = create_mlp(trainX.shape[1], regress=True)
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss='mean_squared_error', optimizer='adam')


print("[INFO] training model...")

model.fit(trainX, trainY, validation_data=(testX, testY),
	epochs=200, batch_size=8)

model.save('TestBat_model.mod')

# %%
import csv
import keras
import pandas as pd

predict=pd.read_csv("drive/My Drive/Project/TestBatting.csv")
labels = ["Innings","BatAvg", "StrikeRate", "FiftyPlus"]
predictList=(predict[labels])


model=keras.models.load_model('TestBat_model.mod')
results=model.predict(predictList)
results=results


output = results.tolist()
names = (predict["Name"])
types = (predict["Type"])


myFile = open('TestBatResults.csv', 'w')   
with myFile:  
    myFields = ['Name','Type' ,'Runs']
    writer = csv.DictWriter(myFile, fieldnames=myFields)    
    writer.writeheader()
    
    for i in range(len(output)):
      writer.writerow({'Name' : names[i], 'Type' : types[i], 'Runs': output[i][0]})

# making data frame from csv file 
data = pd.read_csv("TestBatResults.csv")

# creating a rank column and passing the returned rank series 
data["Rank"] = data["Runs"].rank(ascending=0)

# sorting w.r.t name column 
data.sort_values("Rank", inplace = True)  

export_csv = data.to_csv ('TestBatResults.csv', index = None, header=True)

data
# Out:
#                     Name                  Type       Runs  Rank
# 0           Kusal Mendis  Wicketkeeper batsman  44.919624   1.0
# 1         Angelo Mathews            Allrounder  44.338959   2.0
# 11    Dimuth Karunaratne       Opening batsman  42.948837   3.0
# 10          Kusal Perera  Wicketkeeper batsman  40.351257   4.0
# 4        Oshada Fernando               Batsman  37.308907   5.0
# 6     Niroshan Dickwella  Wicketkeeper batsman  35.817726   6.0
# 3       Dinesh Chandimal  Wicketkeeper batsman  35.778225   7.0
# 2           Roshen Silva               Batsman  35.726528   8.0
# 25   Dhananjaya de Silva            Allrounder  31.335958   9.0
# 5   Danushka Gunathilaka            Allrounder  31.101877  10.0
# 7      Lahiru Thirimanne     Top-order batsman  30.437096  11.0
# 13       Akila Dananjaya            Allrounder  30.168978  12.0
# 8   Malinda Pushpakumara            Allrounder  24.411371  13.0
# 15    Lasith Embuldeniya                Bowler  23.405764  14.0
# 22      Lakshan Sandakan                Bowler  19.354288  15.0
# 21   Chamika Karunaratne                Bowler  18.509119  16.0
# 18         Lahiru Gamage                Bowler  18.118965  17.0
# 19         Kaushal Silva  Wicketkeeper batsman  17.527933  18.0
# 12        Rangana Herath                Bowler  16.747326  19.0
# 9        Dilruwan Perera            Allrounder  15.667503  20.0
# 16       Vishwa Fernando                Bowler  15.630821  21.0
# 23       Mahela Udawatte               Batsman  15.344652  22.0
# 24   Dushmantha Chameera                Bowler  14.064925  23.0
# 20         Kasun Rajitha                Bowler  13.707931  24.0
# 14        Suranga Lakmal                Bowler  10.221107  25.0
# 17         Lahiru Kumara                Bowler   9.883663  26.0
